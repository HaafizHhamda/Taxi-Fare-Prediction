# %%
# Package
import pandas as pd
import pickle

# %%
# load model 
with open('best_random_forest_regressor.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
# Input data
new_data = pd.DataFrame([{
    'Trip_Distance_km':40,
    'Time_of_Day':'Evening',
    'Day_of_Week':'Unknown', 
    'Passenger_Count':1.0000,
    'Traffic_Conditions':'Low',
    'Weather':'Unknown',
    'Base_Fare':3.0200,
    'Per_Km_Rate':0.8600,
    'Per_Minute_Rate':0.3900,
    'Trip_Duration_Minutes':120.6100
}])
new_data
# Out:
#    Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0                40     Evening     Unknown              1.0
#
#   Traffic_Conditions  Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                Low  Unknown       3.02         0.86             0.39
#
#    Trip_Duration_Minutes
# 0                 120.61

# %%
y_pred = loaded_model.predict(new_data)
y_pred
# Out:
# array([80.85346754])
